# %% [markdown]
# # Guía Completa de Markdown para Notebooks Profesionales

# %% [markdown]
# # 🌟 Introducción a Markdown (MD) - Plantilla 2026
#
# Markdown es un lenguaje de marcado ligero que permite **dar formato al texto de manera simple y legible**.
# Se usa ampliamente en archivos `README.md`, documentación de proyectos y celdas de texto en *Jupyter Notebooks*.
#
# ---
#
# ## 📘 Índice
# 1. [Encabezados y estructura](#encabezados-y-estructura)
# 2. [Énfasis y formato](#enfasis-y-formato)
# 3. [Listas y viñetas](#listas-y-vinetas)
# 4. [Enlaces e imágenes](#enlaces-e-imagenes)
# 5. [Citas y código](#citas-y-codigo)
# 6. [Tablas](#tablas)
# 7. [Hooks e índices](#hooks-e-indices)
# 8. [Consejos README/Jupyter](#consejos-readme-jupyter)
# 9. [Recursos](#recursos)
#
# ---
#
# ## Encabezados y estructura
#
# # Título 1 (H1)
# ## Título 2 (H2)
# ### Título 3 (H3)

# %% [markdown]
# ---
# 🎨 <span style="color:#3498db">Formato de Texto

# %% [markdown]
# **Texto en negrita**
#
# *Texto en cursiva*
#
# ***Texto en negrita y cursiva***
#
# ~~Texto tachado~~
#
# `Código inline`

# %% [markdown]
# ---
# <span style="color:#3498db">Colores y estilos avanzados (HTML en Markdown)

# %% [markdown]
# <span style="color:red">Texto en rojo</span>
#
# <span style="color:#3498db">Texto en azul</span>
#
# <span style="color:green; font-weight:bold">Texto verde y negrita</span>
#
# <span style="background-color:yellow">Texto con fondo amarillo</span>
#
# <span style="font-size:20px">Texto grande</span>
#
# <span style="font-family:monospace">Texto monoespaciado</span>

# %% [markdown]
# ---
# <span style="color:#3498db">Resaltados especiales

# %% [markdown]
# <div style="background-color:#e8f4fd; padding:10px; border-left:4px solid #3498db; margin:10px 0; color:#2c3e50;">
# <strong>💡 Nota importante:</strong> Información relevante aquí
# </div>
#
# <div style="background-color:#fff3cd; padding:10px; border-left:4px solid #ffc107; margin:10px 0; color:#2c3e50;">
# <strong>⚠️ Advertencia:</strong> Algo que tener en cuenta
# </div>
#
# <div style="background-color:#d1ecf1; padding:10px; border-left:4px solid #17a2b8; margin:10px 0; color:#2c3e50;">
# <strong>ℹ️ Información:</strong> Datos adicionales
# </div>
#
# <div style="background-color:#d4edda; padding:10px; border-left:4px solid #28a745; margin:10px 0; color:#2c3e50;">
# <strong>✅ Éxito:</strong> Operación completada
# </div>

# %% [markdown]
# ---
# 📋 <span style="color:#3498db">Listas

# %% [markdown]
# Listas con viñetas

# %% [markdown]
# - Elemento 1
# - Elemento 2
#   - Subelemento 2.1
#   - Subelemento 2.2
# - Elemento 3
#
# * También funciona con asteriscos
# + Y con signos más

# %% [markdown]
# Listas numeradas

# %% [markdown]
# 1. Primer elemento
# 2. Segundo elemento
#    1. Subelemento numerado
#    2. Otro subelemento
# 3. Tercer elemento

# %% [markdown]
# Listas de tareas

# %% [markdown]
# - [x] Tarea completada
# - [ ] Tarea pendiente
# - [x] Otra tarea hecha
# - [ ] Falta esta

# %% [markdown]
# ---
# 🔗 <span style="color:#3498db">Enlaces e Imágenes

# %% [markdown]
# Enlaces

# %% [markdown]
# [Página principal Nuclio](https://tech.nuclio.school/login/index.php)
#
# [Página principal Nuclio](https://tech.nuclio.school/login/index.php "Info adicional")
#
# <https://tech.nuclio.school/login/index.php> (enlace directo)

# %% [markdown]
# Imágenes

# %% [markdown]
# ![Texto alternativo](Nuclio.png)
#
# ![Imagen con título](Nuclio.png "Título de la imagen")
#
# <!-- Imagen con tamaño específico -->
# <img src="Nuclio.png" alt="Descripción" width="200" height="100">
#
# <!-- Imagen centrada -->
# <div align="center">
# <img src="Nuclio.png" alt="Descripción" width="400">
# </div>

# %% [markdown]
# <span style="color:#3498db">Imágenes desde URLs

# %% [markdown]
# ![Logo Python](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/110px-Python-logo-notext.svg.png)

# %% [markdown]
# <span style="color:#3498db">Emojis

# %% [markdown]
# 😀 😃 😄 😁 😆 😅 🤣 😂 🙂 🙃 😉 😊 😇
# 🔥 💡 ⚡ 🎯 📊 📈 📉 💻 🖥️ 📱 ⚙️ 🔧
# ✅ ❌ ⚠️ ℹ️ 🚀 🎉 👍 👎 💪 🧠 📝 📚

# %% [markdown]
# <span style="color:#3498db">Badges personalizados

# %% [markdown]
# <span style="background-color:#28a745; color:white; padding:2px 8px; border-radius:12px; font-size:12px;">COMPLETADO</span>
# <span style="background-color:#dc3545; color:white; padding:2px 8px; border-radius:12px; font-size:12px;">PENDIENTE</span>
# <span style="background-color:#ffc107; color:black; padding:2px 8px; border-radius:12px; font-size:12px;">EN PROGRESO</span>

# %% [markdown]
# <span style="color:#3498db">Centrar contenido

# %% [markdown]
# <div align="center">
# <h2>Título Centrado</h2>
# <p>Párrafo centrado</p>
# </div>

# %% [markdown]
# <div align="center">
# <h2>Título Centrado</h2>
# <p>Párrafo centrado</p>
# </div>

# %% [markdown]
# Separadores decorativos

# %% [markdown]
# <hr style="border:none; height:2px; background:linear-gradient(to right, #3498db, #e74c3c, #f39c12);">
#
# <hr style="border:none; height:1px; background:#ddd;">
#
# <div style="text-align:center; margin:20px 0;">
# - • • • •
# </div>

# %% [markdown]
# ### 📱 <span style="color:#3498db">Estructura de Proyecto Profesional

# %% [markdown]
# Portada del notebook

# %% [markdown]
# <div align="center">
# <h1 style="color:#2c3e50;">📊 Introducción a GIT</h1>
# <h2 style="color:#34495e;">README y opciones con markdown</h2>
#
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/6/62/MySQL.svg/640px-MySQL.svg.png" width="200">
#
# **Nuclio Digital School**
# *Módulo: Introducción a ML*
#
# ---
#
# **Autor:** Tu Nombre
# **Fecha:** 25 de Febrero, 2026
# **Versión:** 1.0
#
# </div>
